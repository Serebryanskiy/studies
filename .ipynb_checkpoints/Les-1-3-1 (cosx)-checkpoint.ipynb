# %%
# %matplotlib inline
import nympy as np
import matplotlib.pyplot as plt

#y=cos(k*x)


def drawcos(k):
    x=[];y=[];
    for i in range(-10000,10000):
        _x=i/1000
        _y=math.cos(k*_x)
        x.append(_x)
        y.append(_y)
    plt.plot(x,y)
drawcos(1)
drawcos(0.5)
