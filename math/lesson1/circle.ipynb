# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import numpy as np
# x** 2 + y** 2= R ** 2   

y ** 2 = R ** 2 - x ** 2

# (x - x0)** 2 + (y -y0)** 2= R ** 2     уравнение круга проходящего
# ( (y -y0)** 2 = R ** 2 - (x - x0)** 2  через точки x0 и y0
# y = sqrt(R ** 2 - (x - x0)** 2 ) 

x = [];
y = [];
minusy = []


def circle(x0, y0, R):
    for i in range(-1000, 1000):
        _x = i / 100
        underroot = R ** 2 - (_x - x0) ** 2
        if underroot >= 0:
            _y = math.sqrt(underroot)
            x.append(_x)
            y.append(_y)
            minusy.append(-_y)
    plt.polar(x, y)


def polarcircle(R):
    x=np.linspace(-1,1,101)
    y=np.sqrt(R**2-np.power(x,2))
    plt.polar(x,y)
    plt.polar(x,-y)

    
polarcircle(1)
